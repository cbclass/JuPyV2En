# %%
from questionsE import *

Q1 = create_int_input_widget("Q1: What is the output of the following code segment?",
'''value = 0
for i in range(1,5):
    value = value + i
print(value)''',
10,0)

Q2 = create_int_input_widget("Q2: What is the output of the following code segment?",
'''value = 0
for i in range(3):
    value = value + i
print(value)''',
3,0)
  
    
Q3 = create_int_input_widget("Q3: What is the output of the following code segment?",
'''value = 0
for i in range(-3):
    value = value + i
print(value)''',
0,0)
 
    
Q4 = create_int_input_widget("Q4: What is the output of the following code segment?",
'''value = 0
for i in range(-10,10):
    value = value + i
print(value)''',
-10,0)    
    
 
    
Q5 = create_int_input_widget("Q5: What is the output of the following code segment?",
'''value = 0
for i in range(1,5,2):
    value = value + i
print(value)''',
4,0)  

 
Q6 = create_int_input_widget("Q6: What is the output of the following code segment?",
'''value = 0
for i in range(1,5,-1):
    value = value + i
print(value)''',
0,1)      
    
display(Q1)
display(Code('\n'))
display(Q2)
display(Code('\n'))
display(Q3)
display(Code('\n'))
display(Q4)
display(Code('\n'))
display(Q5)
display(Code('\n'))
display(Q6)
# Out:
# ...
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
# ...
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
# ...
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
# ...
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
# ...
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
# ...
